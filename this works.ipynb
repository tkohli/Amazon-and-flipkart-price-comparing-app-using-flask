# %%
import csv
from bs4 import BeautifulSoup
from msedge.selenium_tools import Edge, EdgeOptions
import pandas as pd
import csv
import json
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import pandas as pd
import time

# %%
q = input("Enter product name (Searching on flipkart)")
q = q.replace(" ","+")
test = []
names = []
flipPrices = []
prodNames = []
info,price = [],[]
url = "https://flipkart.com/search?q="
# query to search for.
#     q = input("Enter a query: ")
file_name = q.replace(" ", "_")
# response recieved in bytes
resp = requests.get(url+q)
# parsing response content using BeautifulSoup class, so that we can perform operations on it.
parsed_html = bs(resp.content, 'html.parser')
# data cleaning
raw_data = parsed_html.find("script", attrs={"id":"is_script"})
data = raw_data.contents[0].replace("window.__INITIAL_STATE__ = ","").replace(";","")
json_data = json.loads(data)
req_data = json_data["pageDataV4"]["page"]["data"]["10003"]   #[10]["widget"]["data"]["products"][3]["productInfo"]
#req_json_data = json_data["seoMeta"]["answerBox"]["data"]["renderableComponents"][0]["value"]["data"]

data_list = []
# print(len(req_data))
try:
    for i in range(1, len(req_data)):
        d = {}
        jd = req_data[i]["widget"]["data"]["products"]
        # print(len(jd))
        # print("i: ", i, end="\n")
        for j in range(len(jd)):
            jd2 = jd[j]["productInfo"]["value"]

            d["title"] = jd2["titles"]["title"]
            d["keySpecs"] = jd2["keySpecs"]
            d["rating"] = jd2["rating"]["average"]
            d["ratingCount"] = jd2["rating"]["count"]
            d["price"] = jd2["pricing"]["finalPrice"]["value"]
#                 d["warranty"] = jd2["warrantySummary"]
            d["url"] = jd2["smartUrl"]

            # You can uncomment below lines if you want to print json output on terminal

            # print("Title: ",jd2["titles"]["title"],end="\n")
            # print("key specs: ", jd2["keySpecs"], end="\n")
            # print("Rating: ", jd2["rating"]["average"], end="\n")
            # print("Total ratings: ", jd2["rating"]["count"], end="\n")
            # print("Price: ", jd2["pricing"]["finalPrice"]["value"],end="\n")
            # print("warranty: ", jd2["warrantySummary"], end="\n")
            # print("Smart url: ", jd2["smartUrl"], end="\n")
        data_list.append(d)


except:
    pass 
# dumping data to result.json file
#     print(list(data_list))
with open("flipkart"+'.json', 'w') as fp:
     json.dump(data_list, fp)

# Now let us write our data to csv file
data_file = open("flipkart"+'.csv', 'w') 

# create the csv writer object 
csv_writer = csv.writer(data_file) 

# Counter variable used for writing  
# headers to the CSV file 
count = 0

for data in data_list:
    if count == 0: 

        # Writing headers of CSV file 
        header = data.keys() 
        csv_writer.writerow(header) 
        count += 1
    # Writing data of CSV file 

    csv_writer.writerow(data.values()) 


with open('flipkart.csv') as csv_file:
    reader = csv.reader(csv_file, delimiter=',')
    rows = list(reader)
i,j = 0,2
while i in range(len(rows)):
    try:
        name = rows[j][0]
        #             name = " ".join(name.split(' ')[0:2])
#         print(name)
#         print("name = ",name)
        names.append(name)
        i += 1
        j += 2
    except:
            break
            
            
print("Best results",len(names))
#     print(names,len(names))
if len(names) < 10:
    f = open("flipkart.csv", "w")
    f.truncate()
    f.close()
    flipkart_url = "https://www.flipkart.com/search?q=" + q
    print(flipkart_url)
    uClient = uReq(flipkart_url)
    flipkartPage = uClient.read()
    uClient.close()
    flipkart_html = bs(flipkartPage, "html.parser")
    bigboxes = flipkart_html.find_all("a", {"class": "s1Q9rs"})
    soup = BeautifulSoup(flipkartPage, 'html.parser')
    info = soup.select("[class~=s1Q9rs]")
    if info == []:
        info = soup.select("[class~=IRpwTa]")
        
    flipPrices = soup.select("[class =_30jeq3]")
    prodNames = [i.get('title') for i in info]
    names = prodNames
    df = pd.DataFrame(list(zip(prodNames, flipPrices)), 
                   columns =['product_name', 'Flipkart_price']) 
    df.to_csv('test.csv')
    print(df,"brooooooooooooooooooo")

else:
    with open('flipkart.csv') as csv_file:
        reader = csv.reader(csv_file, delimiter=',')
        rows = list(reader)
#     i,j = 0,2
#     while i in range(len(rows)):
#         try:
#             name = rows[j][0]
#             #             name = " ".join(name.split(' ')[0:2])
#         #     print(name)
#     #         print("name = ",name)
#             names.append(name)
#             i += 1
#             j += 2
#         except:
#                 break

    i,j = 0,2
    while i in range(len(rows)):
        try:
            price = rows[j][4]
#             price = price[i].text
#             print("price = ",price)
            flipPrices.append(price)
            i += 1
            j += 2
        except:
            break
    df = pd.DataFrame(list(zip(names, flipPrices)), 
               columns =['Product_name', 'Flipkart_price'])
    
    df.to_csv('test.csv')
    print(df)


data_file.close()
# Out:
# Enter product name (Searching on flipkart)clocks
# Best results 0
# https://www.flipkart.com/search?q=clocks
#                                          product_name Flipkart_price
# 0              AJANTA Analog 33 cm X 33 cm Wall Clock         [₹499]
# 1   KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock         [₹329]
# 2          AJANTA Analog 26.5 cm X 26.5 cm Wall Clock         [₹254]
# 3    DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock         [₹449]
# 4              AJANTA Analog 32 cm X 32 cm Wall Clock         [₹429]
# 5              AJANTA Analog 24 cm X 24 cm Wall Clock         [₹249]
# 6              AJANTA Analog 20 cm X 20 cm Wall Clock         [₹228]
# 7              mishty Analog 28 cm X 28 cm Wall Clock         [₹329]
# 8   Brothers creation Analog 26 cm X 26 cm Wall Clock         [₹299]
# 9              AJANTA Analog 28 cm X 28 cm Wall Clock         [₹289]
# 10             AJANTA Analog 32 cm X 32 cm Wall Clock         [₹429]
# 11         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock         [₹399]
# 12          Timex Analog 30.5 cm X 30.5 cm Wall Clock         [₹653]
# 13              Flipkart SmartBuy Analog Maroon Clock         [₹469]
# 14        Factorywala Analog 40 cm X 30 cm Wall Clock         [₹286]
# 15                    Sigaram Analog Multicolor Clock         [₹295]
# 16             Justin Analog 20 cm X 20 cm Wall Clock         [₹211]
# 17          Art Amori Analog 38 cm X 45 cm Wall Clock         [₹699]
# 18            AJANTA Digital 26 cm X 26 cm Wall Clock       [₹1,169]
# 19          AJANTA Analog 38 cm X 30.48 cm Wall Clock         [₹569]
# 20          AJANTA Analog 3.5 cm X 20.5 cm Wall Clock         [₹228]
# 21            Sigaram Analog 18 cm X 17 cm Wall Clock         [₹224]
# 22             AJANTA Analog 19 cm X 19 cm Wall Clock         [₹220]
# 23            Harmoso Analog 28 cm X 28 cm Wall Clock         [₹298]
# 24            Sigaram Analog 28 cm X 23 cm Wall Clock         [₹295]
# 25             AJANTA Analog 20 cm X 20 cm Wall Clock         [₹228]
# 26              Titan Analog 30 cm X 30 cm Wall Clock         [₹899]
# 27              Kadio Analog 20 cm X 20 cm Wall Clock         [₹254]
# 28              Titan Analog 30 cm X 30 cm Wall Clock         [₹995]
# 29             AJANTA Analog 33 cm X 33 cm Wall Clock         [₹499]
# 30             AJANTA Analog 35 cm X 35 cm Wall Clock         [₹499]
# 31                      Clothsfab Digital White Clock         [₹315]
# 32       Masstone Analog 30.5 cm X 30.5 cm Wall Clock         [₹286]
# 33          Flipkart SmartBuy Analog Red, Green Clock         [₹288]
# 34         AJANTA Analog 20.5 cm X 20.5 cm Wall Clock         [₹228]
# 35  A&A Plaza Pendulum Wall Clock Analog 36 cm X 3...         [₹286]
# 36           Precisio Analog 25 cm X 25 cm Wall Clock         [₹299]
# 37         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock         [₹401]
# 38       Dinine Craft Analog 31 cm X 31 cm Wall Clock         [₹399]
# 39          Timex Analog 30.5 cm X 30.5 cm Wall Clock         [₹708] brooooooooooooooooooo

# %%
names
# Out:
# ['AJANTA Analog 33 cm X 33 cm Wall Clock',
#  'KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock',
#  'AJANTA Analog 26.5 cm X 26.5 cm Wall Clock',
#  'DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock',
#  'AJANTA Analog 32 cm X 32 cm Wall Clock',
#  'AJANTA Analog 24 cm X 24 cm Wall Clock',
#  'AJANTA Analog 20 cm X 20 cm Wall Clock',
#  'mishty Analog 28 cm X 28 cm Wall Clock',
#  'Brothers creation Analog 26 cm X 26 cm Wall Clock',
#  'AJANTA Analog 28 cm X 28 cm Wall Clock',
#  'AJANTA Analog 32 cm X 32 cm Wall Clock',
#  'AJANTA Analog 31.3 cm X 31.3 cm Wall Clock',
#  'Timex Analog 30.5 cm X 30.5 cm Wall Clock',
#  'Flipkart SmartBuy Analog Maroon Clock',
#  'Factorywala Analog 40 cm X 30 cm Wall Clock',
#  'Sigaram Analog Multicolor Clock',
#  'Justin Analog 20 cm X 20 cm Wall Clock',
#  'Art Amori Analog 38 cm X 45 cm Wall Clock',
#  'AJANTA Digital 26 cm X 26 cm Wall Clock',
#  'AJANTA Analog 38 cm X 30.48 cm Wall Clock',
#  'AJANTA Analog 3.5 cm X 20.5 cm Wall Clock',
#  'Sigaram Analog 18 cm X 17 cm Wall Clock',
#  'AJANTA Analog 19 cm X 19 cm Wall Clock',
#  'Harmoso Analog 28 cm X 28 cm Wall Clock',
#  'Sigaram Analog 28 cm X 23 cm Wall Clock',
#  'AJANTA Analog 20 cm X 20 cm Wall Clock',
#  'Titan Analog 30 cm X 30 cm Wall Clock',
#  'Kadio Analog 20 cm X 20 cm Wall Clock',
#  'Titan Analog 30 cm X 30 cm Wall Clock',
#  'AJANTA Analog 33 cm X 33 cm Wall Clock',
#  'AJANTA Analog 35 cm X 35 cm Wall Clock',
#  'Clothsfab Digital White Clock',
#  'Masstone Analog 30.5 cm X 30.5 cm Wall Clock',
#  'Flipkart SmartBuy Analog Red, Green Clock',
#  'AJANTA Analog 20.5 cm X 20.5 cm Wall Clock',
#  'A&A Plaza Pendulum Wall Clock Analog 36 cm X 32 cm Wall Clock',
#  'Precisio Analog 25 cm X 25 cm Wall Clock',
#  'AJANTA Analog 31.3 cm X 31.3 cm Wall Clock',
#  'Dinine Craft Analog 31 cm X 31 cm Wall Clock',
#  'Timex Analog 30.5 cm X 30.5 cm Wall Clock']

# %%
import pandas as pd
df = pd.read_csv("test.csv", sep=",")
df.head(100)
# Out:
#     Unnamed: 0                                       product_name  \
# 0            0             AJANTA Analog 33 cm X 33 cm Wall Clock
# 1            1  KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock
# 2            2         AJANTA Analog 26.5 cm X 26.5 cm Wall Clock
# 3            3   DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock
# 4            4             AJANTA Analog 32 cm X 32 cm Wall Clock
# 5            5             AJANTA Analog 24 cm X 24 cm Wall Clock
# 6            6             AJANTA Analog 20 cm X 20 cm Wall Clock
# 7            7             mishty Analog 28 cm X 28 cm Wall Clock
# 8            8  Brothers creation Analog 26 cm X 26 cm Wall Clock
# 9            9             AJANTA Analog 28 cm X 28 cm Wall Clock
# 10          10             AJANTA Analog 32 cm X 32 cm Wall Clock
# 11          11         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock
# 12          12          Timex Analog 30.5 cm X 30.5 cm Wall Clock
# 13          13              Flipkart SmartBuy Analog Maroon Clock
# 14          14        Factorywala Analog 40 cm X 30 cm Wall Clock
# 15          15                    Sigaram Analog Multicolor Clock
# 16          16             Justin Analog 20 cm X 20 cm Wall Clock
# 17          17          Art Amori Analog 38 cm X 45 cm Wall Clock
# 18          18            AJANTA Digital 26 cm X 26 cm Wall Clock
# 19          19          AJANTA Analog 38 cm X 30.48 cm Wall Clock
# 20          20          AJANTA Analog 3.5 cm X 20.5 cm Wall Clock
# 21          21            Sigaram Analog 18 cm X 17 cm Wall Clock
# 22          22             AJANTA Analog 19 cm X 19 cm Wall Clock
# 23          23            Harmoso Analog 28 cm X 28 cm Wall Clock
# 24          24            Sigaram Analog 28 cm X 23 cm Wall Clock
# 25          25             AJANTA Analog 20 cm X 20 cm Wall Clock
# 26          26              Titan Analog 30 cm X 30 cm Wall Clock
# 27          27              Kadio Analog 20 cm X 20 cm Wall Clock
# 28          28              Titan Analog 30 cm X 30 cm Wall Clock
# 29          29             AJANTA Analog 33 cm X 33 cm Wall Clock
# 30          30             AJANTA Analog 35 cm X 35 cm Wall Clock
# 31          31                      Clothsfab Digital White Clock
# 32          32       Masstone Analog 30.5 cm X 30.5 cm Wall Clock
# 33          33          Flipkart SmartBuy Analog Red, Green Clock
# 34          34         AJANTA Analog 20.5 cm X 20.5 cm Wall Clock
# 35          35  A&A Plaza Pendulum Wall Clock Analog 36 cm X 3...
# 36          36           Precisio Analog 25 cm X 25 cm Wall Clock
# 37          37         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock
# 38          38       Dinine Craft Analog 31 cm X 31 cm Wall Clock
# 39          39          Timex Analog 30.5 cm X 30.5 cm Wall Clock
#
#                        Flipkart_price
# 0     <div class="_30jeq3">₹499</div>
# 1     <div class="_30jeq3">₹329</div>
# 2     <div class="_30jeq3">₹254</div>
# 3     <div class="_30jeq3">₹449</div>
# 4     <div class="_30jeq3">₹429</div>
# 5     <div class="_30jeq3">₹249</div>
# 6     <div class="_30jeq3">₹228</div>
# 7     <div class="_30jeq3">₹329</div>
# 8     <div class="_30jeq3">₹299</div>
# 9     <div class="_30jeq3">₹289</div>
# 10    <div class="_30jeq3">₹429</div>
# 11    <div class="_30jeq3">₹399</div>
# 12    <div class="_30jeq3">₹653</div>
# 13    <div class="_30jeq3">₹469</div>
# 14    <div class="_30jeq3">₹286</div>
# 15    <div class="_30jeq3">₹295</div>
# 16    <div class="_30jeq3">₹211</div>
# 17    <div class="_30jeq3">₹699</div>
# 18  <div class="_30jeq3">₹1,169</div>
# 19    <div class="_30jeq3">₹569</div>
# 20    <div class="_30jeq3">₹228</div>
# 21    <div class="_30jeq3">₹224</div>
# 22    <div class="_30jeq3">₹220</div>
# 23    <div class="_30jeq3">₹298</div>
# 24    <div class="_30jeq3">₹295</div>
# 25    <div class="_30jeq3">₹228</div>
# 26    <div class="_30jeq3">₹899</div>
# 27    <div class="_30jeq3">₹254</div>
# 28    <div class="_30jeq3">₹995</div>
# 29    <div class="_30jeq3">₹499</div>
# 30    <div class="_30jeq3">₹499</div>
# 31    <div class="_30jeq3">₹315</div>
# 32    <div class="_30jeq3">₹286</div>
# 33    <div class="_30jeq3">₹288</div>
# 34    <div class="_30jeq3">₹228</div>
# 35    <div class="_30jeq3">₹286</div>
# 36    <div class="_30jeq3">₹299</div>
# 37    <div class="_30jeq3">₹401</div>
# 38    <div class="_30jeq3">₹399</div>
# 39    <div class="_30jeq3">₹708</div>

# %%
print(len(names),len(flipPrices))
# flipPrices
# Out:
# 24 24

# %%
from bs4 import BeautifulSoup
import requests
import time
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

flipkart=''
ebay=''
amazon=''
olx=''

amazonlist = []
amazonName = []
i = 0
while i in range(len(names)):
    print(names[i])
    def amazon(name):
            try:
                global amazon
                name = " ".join(name.split(' ')[0:2])
                name1 = name.replace(" ","-")
                name2 = name.replace(" ","+")
                amazon=f'https://www.amazon.in/{name1}/s?k={name2}'
                res = requests.get(f'https://www.amazon.in/{name1}/s?k={name2}',headers=headers)
                print("\nSearching in amazon:")
                soup = BeautifulSoup(res.text,'html.parser')
                amazon_page = soup.select('.a-color-base.a-text-normal')
                amazon_page_length = int(len(amazon_page))
                for i in range(0,amazon_page_length):
                    name = name.upper()
                    amazon_name = soup.select('.a-color-base.a-text-normal')[i].getText().strip().upper()
                    if name in amazon_name[0:20]:
                        amazon_name = soup.select('.a-color-base.a-text-normal')[i].getText().strip().upper()
                        amazon_price = soup.select('.a-price-whole')[i].getText().strip().upper()
                        amazonlist.append(amazon_price)
                        print("Amazon:")
                        print(amazon_name)
                        amazonName.append(amazon_name)
                        print("₹"+amazon_price)
                        print("-----------------------")
                        break
                    else:
                        i+=1
                        i=int(i)
                        if i==amazon_page_length:
                            print("amazon : No product found!")
                            print("-----------------------")
                            amazon_price = '0'
                            amazonlist.append(amazon_price)
                            amazonName.append("No similar product")
                            break
                
                return amazon_price
            except:
                print("amazon: No product found!")
                print("-----------------------")
                amazon_price = '0'
                amazonlist.append(amazon_price)
                amazonName.append("No similar product")
            return amazon_price
    amazon_price = amazon(names[i])
    flipkart=''
    ebay=''
    croma=''
    amazon=''
    olx=''
    i += 1
flip = flipPrices
idk = []
for i in range(len(flip)):
#     x = 
    try:
        x = flip[i].text.replace('₹','')
        print(x)
        idk.append(x)
    except:
        idk = test
df = pd.DataFrame(list(zip(names,idk,amazonName, amazonlist)), 
               columns =["Product_name_Flipkart","Flipkart_price",'Product_name_Amazon', 'Amazon_price'])
    
df.to_csv('flipkartandamazon.csv')
df
# Out:
# AJANTA Analog 33 cm X 33 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 40 CM X 40 CM WALL CLOCK (BLACK, WITH GLASS)
# ₹544
# -----------------------
# KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# KWF INTERNATIONAL ANALOG WALL CLOCK (BLACK, WITH GLASS) (MULTI)
# ₹418
# -----------------------
# AJANTA Analog 26.5 cm X 26.5 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 32 cm X 32 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 24 cm X 24 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 20 cm X 20 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# mishty Analog 28 cm X 28 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# MISHTY ANALOG WALL CLOCK (MULTI_1.5 INCH X 12.5 INCH X 12.5 INCH)
# ₹388
# -----------------------
# Brothers creation Analog 26 cm X 26 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 28 cm X 28 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 32 cm X 32 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 31.3 cm X 31.3 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Timex Analog 30.5 cm X 30.5 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Flipkart SmartBuy Analog Maroon Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Factorywala Analog 40 cm X 30 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Sigaram Analog Multicolor Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Justin Analog 20 cm X 20 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Art Amori Analog 38 cm X 45 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# ART AMORI BEAUTIFUL FLAMINGO COQUILLAGES AND STARFISH 3 PIECE MDF PAINTING
# ₹349
# -----------------------
# AJANTA Digital 26 cm X 26 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA DIGITAL CLOCK-DC-037
# ₹915
# -----------------------
# AJANTA Analog 38 cm X 30.48 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 3.5 cm X 20.5 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Sigaram Analog 18 cm X 17 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 19 cm X 19 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Harmoso Analog 28 cm X 28 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Sigaram Analog 28 cm X 23 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 20 cm X 20 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Titan Analog 30 cm X 30 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Kadio Analog 20 cm X 20 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Titan Analog 30 cm X 30 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 33 cm X 33 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# AJANTA Analog 35 cm X 35 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Clothsfab Digital White Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Masstone Analog 30.5 cm X 30.5 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Flipkart SmartBuy Analog Red, Green Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 20.5 cm X 20.5 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# A&A Plaza Pendulum Wall Clock Analog 36 cm X 32 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# Precisio Analog 25 cm X 25 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# AJANTA Analog 31.3 cm X 31.3 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (WHITE, WITH GLASS)
# ₹844
# -----------------------
# Dinine Craft Analog 31 cm X 31 cm Wall Clock
#
# Searching in amazon:
# Amazon:
# DININE CRAFT DESIGNER WOODEN WALL SHELVES KEYHOLDER ( WITH 7 HOOKS KEYHOLDER)
# ₹399
# -----------------------
# Timex Analog 30.5 cm X 30.5 cm Wall Clock
#
# Searching in amazon:
# amazon : No product found!
# -----------------------
# 499
# 329
# 254
# 449
# 429
# 249
# 228
# 329
# 299
# 289
# 429
# 399
# 653
# 469
# 286
# 295
# 211
# 699
# 1,169
# 569
# 228
# 224
# 220
# 298
# 295
# 228
# 899
# 254
# 995
# 499
# 499
# 315
# 286
# 288
# 228
# 286
# 299
# 401
# 399
# 708
#                                 Product_name_Flipkart Flipkart_price  \
# 0              AJANTA Analog 33 cm X 33 cm Wall Clock            499
# 1   KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock            329
# 2          AJANTA Analog 26.5 cm X 26.5 cm Wall Clock            254
# 3    DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock            449
# 4              AJANTA Analog 32 cm X 32 cm Wall Clock            429
# 5              AJANTA Analog 24 cm X 24 cm Wall Clock            249
# 6              AJANTA Analog 20 cm X 20 cm Wall Clock            228
# 7              mishty Analog 28 cm X 28 cm Wall Clock            329
# 8   Brothers creation Analog 26 cm X 26 cm Wall Clock            299
# 9              AJANTA Analog 28 cm X 28 cm Wall Clock            289
# 10             AJANTA Analog 32 cm X 32 cm Wall Clock            429
# 11         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock            399
# 12          Timex Analog 30.5 cm X 30.5 cm Wall Clock            653
# 13              Flipkart SmartBuy Analog Maroon Clock            469
# 14        Factorywala Analog 40 cm X 30 cm Wall Clock            286
# 15                    Sigaram Analog Multicolor Clock            295
# 16             Justin Analog 20 cm X 20 cm Wall Clock            211
# 17          Art Amori Analog 38 cm X 45 cm Wall Clock            699
# 18            AJANTA Digital 26 cm X 26 cm Wall Clock          1,169
# 19          AJANTA Analog 38 cm X 30.48 cm Wall Clock            569
# 20          AJANTA Analog 3.5 cm X 20.5 cm Wall Clock            228
# 21            Sigaram Analog 18 cm X 17 cm Wall Clock            224
# 22             AJANTA Analog 19 cm X 19 cm Wall Clock            220
# 23            Harmoso Analog 28 cm X 28 cm Wall Clock            298
# 24            Sigaram Analog 28 cm X 23 cm Wall Clock            295
# 25             AJANTA Analog 20 cm X 20 cm Wall Clock            228
# 26              Titan Analog 30 cm X 30 cm Wall Clock            899
# 27              Kadio Analog 20 cm X 20 cm Wall Clock            254
# 28              Titan Analog 30 cm X 30 cm Wall Clock            995
# 29             AJANTA Analog 33 cm X 33 cm Wall Clock            499
# 30             AJANTA Analog 35 cm X 35 cm Wall Clock            499
# 31                      Clothsfab Digital White Clock            315
# 32       Masstone Analog 30.5 cm X 30.5 cm Wall Clock            286
# 33          Flipkart SmartBuy Analog Red, Green Clock            288
# 34         AJANTA Analog 20.5 cm X 20.5 cm Wall Clock            228
# 35  A&A Plaza Pendulum Wall Clock Analog 36 cm X 3...            286
# 36           Precisio Analog 25 cm X 25 cm Wall Clock            299
# 37         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock            401
# 38       Dinine Craft Analog 31 cm X 31 cm Wall Clock            399
# 39          Timex Analog 30.5 cm X 30.5 cm Wall Clock            708
#
#                                   Product_name_Amazon Amazon_price
# 0   AJANTA ANALOG 40 CM X 40 CM WALL CLOCK (BLACK,...          544
# 1   KWF INTERNATIONAL ANALOG WALL CLOCK (BLACK, WI...          418
# 2   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 3                                  No similar product            0
# 4   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 5   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 6   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 7   MISHTY ANALOG WALL CLOCK (MULTI_1.5 INCH X 12....          388
# 8                                  No similar product            0
# 9   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 10  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 11  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 12                                 No similar product            0
# 13                                 No similar product            0
# 14                                 No similar product            0
# 15                                 No similar product            0
# 16                                 No similar product            0
# 17  ART AMORI BEAUTIFUL FLAMINGO COQUILLAGES AND S...          349
# 18                        AJANTA DIGITAL CLOCK-DC-037          915
# 19  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 20  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 21                                 No similar product            0
# 22  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 23                                 No similar product            0
# 24                                 No similar product            0
# 25  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 26                                 No similar product            0
# 27                                 No similar product            0
# 28                                 No similar product            0
# 29  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 30  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 31                                 No similar product            0
# 32                                 No similar product            0
# 33                                 No similar product            0
# 34  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 35                                 No similar product            0
# 36                                 No similar product            0
# 37  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 38  DININE CRAFT DESIGNER WOODEN WALL SHELVES KEYH...          399
# 39                                 No similar product            0

# %%
df = pd.DataFrame(list(zip(amazonName, amazonlist)), 
               columns =['Product_name', 'Amazon_price'])
    
print(df)
# len(amazonName)
# Out:
#                                          Product_name Amazon_price
# 0   AJANTA ANALOG 40 CM X 40 CM WALL CLOCK (BLACK,...          544
# 1   KWF INTERNATIONAL ANALOG WALL CLOCK (BLACK, WI...          418
# 2   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 3                                  No similar product            0
# 4   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 5   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 6   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 7   MISHTY ANALOG WALL CLOCK (MULTI_1.5 INCH X 12....          388
# 8                                  No similar product            0
# 9   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 10  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 11  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 12                                 No similar product            0
# 13                                 No similar product            0
# 14                                 No similar product            0
# 15                                 No similar product            0
# 16                                 No similar product            0
# 17  ART AMORI BEAUTIFUL FLAMINGO COQUILLAGES AND S...          349
# 18                        AJANTA DIGITAL CLOCK-DC-037          915
# 19  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 20  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 21                                 No similar product            0
# 22  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 23                                 No similar product            0
# 24                                 No similar product            0
# 25  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 26                                 No similar product            0
# 27                                 No similar product            0
# 28                                 No similar product            0
# 29  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 30  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 31                                 No similar product            0
# 32                                 No similar product            0
# 33                                 No similar product            0
# 34  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 35                                 No similar product            0
# 36                                 No similar product            0
# 37  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 38  DININE CRAFT DESIGNER WOODEN WALL SHELVES KEYH...          399
# 39                                 No similar product            0

# %%
test = flipPrices

# %%
flip = flipPrices

# %%
idk = []

# %%
flip = flipPrices
idk = []
for i in range(len(flip)):
#     x = 
    try:
        x = flip[i].text.replace('₹','')
        print(x)
        idk.append(x)
    except:
        idk = test
# Out:
# 499
# 329
# 254
# 449
# 429
# 249
# 228
# 329
# 299
# 289
# 429
# 399
# 653
# 469
# 286
# 295
# 211
# 699
# 1,169
# 569
# 228
# 224
# 220
# 298
# 295
# 228
# 899
# 254
# 995
# 499
# 499
# 315
# 286
# 288
# 228
# 286
# 299
# 401
# 399
# 708

# %%
# idk[0].replace('₹','')

# %%
idk
# Out:
# ['11999',
#  '7999',
#  '7999',
#  '7999',
#  '10999',
#  '8999',
#  '9499',
#  '11999',
#  '11499',
#  '10499',
#  '11499',
#  '9499',
#  '7999',
#  '9999',
#  '15999',
#  '13999',
#  '10999',
#  '6499',
#  '6499',
#  '7999',
#  '10999',
#  '12999',
#  '11999',
#  '12999']

# %%
flip
# Out:
# ['11999',
#  '7999',
#  '7999',
#  '7999',
#  '10999',
#  '8999',
#  '9499',
#  '11999',
#  '11499',
#  '10499',
#  '11499',
#  '9499',
#  '7999',
#  '9999',
#  '15999',
#  '13999',
#  '10999',
#  '6499',
#  '6499',
#  '7999',
#  '10999',
#  '12999',
#  '11999',
#  '12999']

# %%
# len(flip)
amazonlist

# %%
import csv
# opening the csv file in 'w+' mode

file = open('flipkartandamazon.csv', 'w+', newline ='')
# csv_data = pd.read_csv(csvpath,encoding='iso-8859-1')
# writing the data into the file
with file:    
    write = csv.writer(file)
    write.writerows(names)
    write.writerows(idk)
    write.writerows(amazonName)
    write.writerows(amazonlist)

# %%
df = pd.DataFrame(list(zip(names,idk,amazonName, amazonlist)), 
               columns =["Product_name_Flipkart","Flipkart_price",'Product_name_Amazon', 'Amazon_price'])
    
df
# Out:
#                                 Product_name_Flipkart Flipkart_price  \
# 0              AJANTA Analog 33 cm X 33 cm Wall Clock            499
# 1   KWF INTERNATIONAL Analog 30 cm X 30 cm Wall Clock            329
# 2          AJANTA Analog 26.5 cm X 26.5 cm Wall Clock            254
# 3    DivineCrafts Analog 32.5 cm X 32.5 cm Wall Clock            449
# 4              AJANTA Analog 32 cm X 32 cm Wall Clock            429
# 5              AJANTA Analog 24 cm X 24 cm Wall Clock            249
# 6              AJANTA Analog 20 cm X 20 cm Wall Clock            228
# 7              mishty Analog 28 cm X 28 cm Wall Clock            329
# 8   Brothers creation Analog 26 cm X 26 cm Wall Clock            299
# 9              AJANTA Analog 28 cm X 28 cm Wall Clock            289
# 10             AJANTA Analog 32 cm X 32 cm Wall Clock            429
# 11         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock            399
# 12          Timex Analog 30.5 cm X 30.5 cm Wall Clock            653
# 13              Flipkart SmartBuy Analog Maroon Clock            469
# 14        Factorywala Analog 40 cm X 30 cm Wall Clock            286
# 15                    Sigaram Analog Multicolor Clock            295
# 16             Justin Analog 20 cm X 20 cm Wall Clock            211
# 17          Art Amori Analog 38 cm X 45 cm Wall Clock            699
# 18            AJANTA Digital 26 cm X 26 cm Wall Clock          1,169
# 19          AJANTA Analog 38 cm X 30.48 cm Wall Clock            569
# 20          AJANTA Analog 3.5 cm X 20.5 cm Wall Clock            228
# 21            Sigaram Analog 18 cm X 17 cm Wall Clock            224
# 22             AJANTA Analog 19 cm X 19 cm Wall Clock            220
# 23            Harmoso Analog 28 cm X 28 cm Wall Clock            298
# 24            Sigaram Analog 28 cm X 23 cm Wall Clock            295
# 25             AJANTA Analog 20 cm X 20 cm Wall Clock            228
# 26              Titan Analog 30 cm X 30 cm Wall Clock            899
# 27              Kadio Analog 20 cm X 20 cm Wall Clock            254
# 28              Titan Analog 30 cm X 30 cm Wall Clock            995
# 29             AJANTA Analog 33 cm X 33 cm Wall Clock            499
# 30             AJANTA Analog 35 cm X 35 cm Wall Clock            499
# 31                      Clothsfab Digital White Clock            315
# 32       Masstone Analog 30.5 cm X 30.5 cm Wall Clock            286
# 33          Flipkart SmartBuy Analog Red, Green Clock            288
# 34         AJANTA Analog 20.5 cm X 20.5 cm Wall Clock            228
# 35  A&A Plaza Pendulum Wall Clock Analog 36 cm X 3...            286
# 36           Precisio Analog 25 cm X 25 cm Wall Clock            299
# 37         AJANTA Analog 31.3 cm X 31.3 cm Wall Clock            401
# 38       Dinine Craft Analog 31 cm X 31 cm Wall Clock            399
# 39          Timex Analog 30.5 cm X 30.5 cm Wall Clock            708
#
#                                   Product_name_Amazon Amazon_price
# 0   AJANTA ANALOG 40 CM X 40 CM WALL CLOCK (BLACK,...          544
# 1   KWF INTERNATIONAL ANALOG WALL CLOCK (BLACK, WI...          418
# 2   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 3                                  No similar product            0
# 4   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 5   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 6   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 7   MISHTY ANALOG WALL CLOCK (MULTI_1.5 INCH X 12....          388
# 8                                  No similar product            0
# 9   AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 10  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 11  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 12                                 No similar product            0
# 13                                 No similar product            0
# 14                                 No similar product            0
# 15                                 No similar product            0
# 16                                 No similar product            0
# 17  ART AMORI BEAUTIFUL FLAMINGO COQUILLAGES AND S...          349
# 18                        AJANTA DIGITAL CLOCK-DC-037          915
# 19  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 20  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 21                                 No similar product            0
# 22  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 23                                 No similar product            0
# 24                                 No similar product            0
# 25  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 26                                 No similar product            0
# 27                                 No similar product            0
# 28                                 No similar product            0
# 29  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 30  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 31                                 No similar product            0
# 32                                 No similar product            0
# 33                                 No similar product            0
# 34  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 35                                 No similar product            0
# 36                                 No similar product            0
# 37  AJANTA ANALOG 30.48 CM X 30.48 CM WALL CLOCK (...          844
# 38  DININE CRAFT DESIGNER WOODEN WALL SHELVES KEYH...          399
# 39                                 No similar product            0

# %%
df.to_csv('flipkartandamazon.csv')

# %%
import pandas as pd
df = pd.read_csv("flipkartandamazon.csv", sep=",")
df.head(100)
# Out:
#     Unnamed: 0                          Product_name_Flipkart  Flipkart_price  \
# 0            0                  POCO M3 (Power Black, 128 GB)           11999
# 1            1               realme C12 (Power Silver, 32 GB)            7999
# 2            2                 realme C12 (Power Blue, 32 GB)            7999
# 3            3                     REDMI 9i (Sea Blue, 64 GB)            7999
# 4            4                     POCO M3 (Cool Blue, 64 GB)           10999
# 5            5               realme C12 (Power Silver, 64 GB)            8999
# 6            6              Redmi 9 Prime (Space Blue, 64 GB)            9499
# 7            7                realme 7i (Fusion Green, 64 GB)           11999
# 8            8         realme Narzo 20 (Glory Silver, 128 GB)           11499
# 9            9          realme Narzo 20 (Victory Blue, 64 GB)           10499
# 10          10         realme Narzo 20 (Victory Blue, 128 GB)           11499
# 11          11         realme Narzo 20A (Glory Silver, 64 GB)            9499
# 12          12               REDMI 9i (Midnight Black, 64 GB)            7999
# 13          13          realme Narzo 30A (Laser Black, 64 GB)            9999
# 14          14                   realme 7 (Mist Blue, 128 GB)           15999
# 15          15                    realme 7 (Mist Blue, 64 GB)           13999
# 16          16                   POCO M3 (Power Black, 64 GB)           10999
# 17          17      Infinix Smart HD 2021 (Topaz Blue, 32 GB)            6499
# 18          18  Infinix Smart HD 2021 (Obsidian Black, 32 GB)            6499
# 19          19                 REDMI 9i (Nature Green, 64 GB)            7999
# 20          20                        POCO M3 (Yellow, 64 GB)           10999
# 21          21               realme 7i (Fusion Green, 128 GB)           12999
# 22          22                 realme 7i (Fusion Blue, 64 GB)           11999
# 23          23                realme 7i (Fusion Blue, 128 GB)           12999
#
#                                   Product_name_Amazon Amazon_price
# 0                                  No similar product            0
# 1           REALME C12 (POWER BLUE, 32 GB) (3 GB RAM)       10,430
# 2                                  No similar product            0
# 3    REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)        8,199
# 4          POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)       10,499
# 5                                  No similar product            0
# 6           REDMI 9 (SKY BLUE, 4GB RAM, 64GB STORAGE)        8,799
# 7                    REALME 7I, 4GB RAM, 64GB STORAGE       4,999.
# 8   REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB S...       10,799
# 9                                  No similar product            0
# 10  REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB S...       10,799
# 11  REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB S...       10,799
# 12   REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)        8,199
# 13                                 No similar product            0
# 14                                 No similar product            0
# 15             REALME 7 (MIST BLUE, 64 GB) (6 GB RAM)       14,998
# 16         POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)       10,499
# 17                                 No similar product            0
# 18  INFINIX SMART HD 2021 (OBSIDIAN BLACK,32 GB) (...        8,499
# 19   REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)        8,375
# 20         POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)       10,499
# 21                   REALME 7I, 4GB RAM, 64GB STORAGE       13,889
# 22                   REALME 7I, 4GB RAM, 64GB STORAGE       13,900
# 23                   REALME 7I, 4GB RAM, 64GB STORAGE       4,999.

# %%
test = []
names = []
flipPrices = []
prodNames = []
info,price = [],[]
url = "https://flipkart.com/search?q="
# query to search for.
q = input("Enter product name (Searching on flipkart)")
q = q.replace(" ","+")
#     q = input("Enter a query: ")
file_name = q.replace(" ", "_")
# response recieved in bytes
resp = requests.get(url+q)
# parsing response content using BeautifulSoup class, so that we can perform operations on it.
parsed_html = bs(resp.content, 'html.parser')
# data cleaning
raw_data = parsed_html.find("script", attrs={"id":"is_script"})
data = raw_data.contents[0].replace("window.__INITIAL_STATE__ = ","").replace(";","")
json_data = json.loads(data)
req_data = json_data["pageDataV4"]["page"]["data"]["10003"]   #[10]["widget"]["data"]["products"][3]["productInfo"]
#req_json_data = json_data["seoMeta"]["answerBox"]["data"]["renderableComponents"][0]["value"]["data"]

data_list = []
# print(len(req_data))
try:
    for i in range(1, len(req_data)):
        d = {}
        jd = req_data[i]["widget"]["data"]["products"]
        # print(len(jd))
        # print("i: ", i, end="\n")
        for j in range(len(jd)):
            jd2 = jd[j]["productInfo"]["value"]

            d["title"] = jd2["titles"]["title"]
            d["keySpecs"] = jd2["keySpecs"]
            d["rating"] = jd2["rating"]["average"]
            d["ratingCount"] = jd2["rating"]["count"]
            d["price"] = jd2["pricing"]["finalPrice"]["value"]
#                 d["warranty"] = jd2["warrantySummary"]
            d["url"] = jd2["smartUrl"]

            # You can uncomment below lines if you want to print json output on terminal

            # print("Title: ",jd2["titles"]["title"],end="\n")
            # print("key specs: ", jd2["keySpecs"], end="\n")
            # print("Rating: ", jd2["rating"]["average"], end="\n")
            # print("Total ratings: ", jd2["rating"]["count"], end="\n")
            # print("Price: ", jd2["pricing"]["finalPrice"]["value"],end="\n")
            # print("warranty: ", jd2["warrantySummary"], end="\n")
            # print("Smart url: ", jd2["smartUrl"], end="\n")
        data_list.append(d)


except:
    pass 
# dumping data to result.json file
#     print(list(data_list))
with open("flipkart"+'.json', 'w') as fp:
    json.dump(data_list, fp)

# Now let us write our data to csv file
data_file = open("flipkart"+'.csv', 'w') 

# create the csv writer object 
csv_writer = csv.writer(data_file) 

# Counter variable used for writing  
# headers to the CSV file 
count = 0

for data in data_list:
    if count == 0: 

        # Writing headers of CSV file 
        header = data.keys() 
        csv_writer.writerow(header) 
        count += 1
    # Writing data of CSV file 

    csv_writer.writerow(data.values()) 


with open('flipkart.csv') as csv_file:
    reader = csv.reader(csv_file, delimiter=',')
    rows = list(reader)
i,j = 0,2
while i in range(len(rows)):
    try:
        name = rows[j][0]
        #             name = " ".join(name.split(' ')[0:2])
#         print(name)
#         print("name = ",name)
        names.append(name)
        i += 1
        j += 2
    except:
            break


print("Best results",len(names))
#     print(names,len(names))
if len(names) <= 10:
    flipkart_url = "https://www.flipkart.com/search?q=" + q
    print(flipkart_url)
    uClient = uReq(flipkart_url)
    flipkartPage = uClient.read()
    uClient.close()
    flipkart_html = bs(flipkartPage, "html.parser")
    bigboxes = flipkart_html.find_all("a", {"class": "s1Q9rs"})
    soup = BeautifulSoup(flipkartPage, 'html.parser')
    info = soup.select("[class~=s1Q9rs]")
    flipPrices = soup.select("[class =_30jeq3]")
    prodNames = [i.get('title') for i in info]
    names = prodNames
    df = pd.DataFrame(list(zip(prodNames, flipPrices)), 
                columns =['product_name', 'Flipkart_price']) 
    df.to_csv('flipkart.csv')
    print(df)

else:
    with open('flipkart.csv') as csv_file:
        reader = csv.reader(csv_file, delimiter=',')
        rows = list(reader)
#     i,j = 0,2
#     while i in range(len(rows)):
#         try:
#             name = rows[j][0]
#             #             name = " ".join(name.split(' ')[0:2])
#         #     print(name)
#     #         print("name = ",name)
#             names.append(name)
#             i += 1
#             j += 2
#         except:
#                 break

    i,j = 0,2
    while i in range(len(rows)):
        try:
            price = rows[j][4]
#             price = price[i].text
#             print("price = ",price)
            flipPrices.append(price)
            i += 1
            j += 2
        except:
            break
    df = pd.DataFrame(list(zip(names, flipPrices)), 
            columns =['Product_name', 'Flipkart_price'])

    print(df)
    df.to_csv('flipkart.csv')

data_file.close()

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}

flipkart=''
ebay=''
amazon=''
olx=''

amazonlist = []
amazonName = []
i = 0
while i in range(len(names)):
    print(names[i])
    def amazon(name):
            try:
                global amazon
                name = " ".join(name.split(' ')[0:2])
                name1 = name.replace(" ","-")
                name2 = name.replace(" ","+")
                amazon=f'https://www.amazon.in/{name1}/s?k={name2}'
                res = requests.get(f'https://www.amazon.in/{name1}/s?k={name2}',headers=headers)
                print("\nSearching in amazon:")
                soup = BeautifulSoup(res.text,'html.parser')
                amazon_page = soup.select('.a-color-base.a-text-normal')
                amazon_page_length = int(len(amazon_page))
                for i in range(0,amazon_page_length):
                    name = name.upper()
                    amazon_name = soup.select('.a-color-base.a-text-normal')[i].getText().strip().upper()
                    if name in amazon_name[0:20]:
                        amazon_name = soup.select('.a-color-base.a-text-normal')[i].getText().strip().upper()
                        amazon_price = soup.select('.a-price-whole')[i].getText().strip().upper()
                        amazonlist.append(amazon_price)
                        print("Amazon:")
                        print(amazon_name)
                        amazonName.append(amazon_name)
                        print("₹"+amazon_price)
                        print("-----------------------")
                        break
                    else:
                        i+=1
                        i=int(i)
                        if i==amazon_page_length:
                            print("amazon : No product found!")
                            print("-----------------------")
                            amazon_price = '0'
                            amazonlist.append(amazon_price)
                            amazonName.append("No similar product")
                            break

                return amazon_price
            except:
                print("amazon: No product found!")
                print("-----------------------")
                amazon_price = '0'
                amazonlist.append(amazon_price)
                amazonName.append("No similar product")
            return amazon_price
    amazon_price = amazon(names[i])
    flipkart=''
    ebay=''
    croma=''
    amazon=''
    olx=''
    i += 1

flip = flipPrices
idk = []
for i in range(len(flip)):
#     x = 
    try:
        x = flip[i].text.replace('₹','')
        print(x)
        idk.append(x)
    except:
        idk = test
df = pd.DataFrame(list(zip(names,idk,amazonName, amazonlist)), 
            columns =["Product_name_Flipkart","Flipkart_price",'Product_name_Amazon', 'Amazon_price'])
print(df)   
df.to_csv('flipkartandamazon.csv')
# Out:
# Enter product name (Searching on flipkart)smartphones
# Best results 24
#                                      Product_name Flipkart_price
# 0                   POCO M3 (Power Black, 128 GB)          11999
# 1                realme C12 (Power Silver, 32 GB)           7999
# 2                  realme C12 (Power Blue, 32 GB)           7999
# 3                      REDMI 9i (Sea Blue, 64 GB)           7999
# 4                      POCO M3 (Cool Blue, 64 GB)          10999
# 5                realme C12 (Power Silver, 64 GB)           8999
# 6               Redmi 9 Prime (Space Blue, 64 GB)           9499
# 7                 realme 7i (Fusion Green, 64 GB)          11999
# 8          realme Narzo 20 (Glory Silver, 128 GB)          11499
# 9           realme Narzo 20 (Victory Blue, 64 GB)          10499
# 10         realme Narzo 20 (Victory Blue, 128 GB)          11499
# 11         realme Narzo 20A (Glory Silver, 64 GB)           9499
# 12               REDMI 9i (Midnight Black, 64 GB)           7999
# 13          realme Narzo 30A (Laser Black, 64 GB)           9999
# 14                   realme 7 (Mist Blue, 128 GB)          15999
# 15                    realme 7 (Mist Blue, 64 GB)          13999
# 16                   POCO M3 (Power Black, 64 GB)          10999
# 17      Infinix Smart HD 2021 (Topaz Blue, 32 GB)           6499
# 18  Infinix Smart HD 2021 (Obsidian Black, 32 GB)           6499
# 19                 REDMI 9i (Nature Green, 64 GB)           7999
# 20                        POCO M3 (Yellow, 64 GB)          10999
# 21               realme 7i (Fusion Green, 128 GB)          12999
# 22                 realme 7i (Fusion Blue, 64 GB)          11999
# 23                realme 7i (Fusion Blue, 128 GB)          12999
# POCO M3 (Power Black, 128 GB)
#
# Searching in amazon:
# Amazon:
# POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)
# ₹10,499
# -----------------------
# realme C12 (Power Silver, 32 GB)
#
# Searching in amazon:
# Amazon:
# REALME C12 (POWER BLUE, 32 GB) (3 GB RAM)
# ₹10,430
# -----------------------
# realme C12 (Power Blue, 32 GB)
#
# Searching in amazon:
# Amazon:
# REALME C12 (POWER BLUE, 32 GB) (3 GB RAM)
# ₹10,430
# -----------------------
# REDMI 9i (Sea Blue, 64 GB)
#
# Searching in amazon:
# Amazon:
# REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)
# ₹8,199
# -----------------------
# POCO M3 (Cool Blue, 64 GB)
#
# Searching in amazon:
# Amazon:
# POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)
# ₹10,499
# -----------------------
# realme C12 (Power Silver, 64 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# Redmi 9 Prime (Space Blue, 64 GB)
#
# Searching in amazon:
# Amazon:
# REDMI 9 (SKY BLUE, 4GB RAM, 64GB STORAGE)
# ₹8,799
# -----------------------
# realme 7i (Fusion Green, 64 GB)
#
# Searching in amazon:
# Amazon:
# REALME 7I, 4GB RAM, 64GB STORAGE
# ₹4,999.
# -----------------------
# realme Narzo 20 (Glory Silver, 128 GB)
#
# Searching in amazon:
# Amazon:
# REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB STORAGE
# ₹12,999
# -----------------------
# realme Narzo 20 (Victory Blue, 64 GB)
#
# Searching in amazon:
# Amazon:
# REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB STORAGE
# ₹12,999
# -----------------------
# realme Narzo 20 (Victory Blue, 128 GB)
#
# Searching in amazon:
# Amazon:
# REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB STORAGE
# ₹4,999.
# -----------------------
# realme Narzo 20A (Glory Silver, 64 GB)
#
# Searching in amazon:
# Amazon:
# REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB STORAGE
# ₹10,799
# -----------------------
# REDMI 9i (Midnight Black, 64 GB)
#
# Searching in amazon:
# Amazon:
# REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)
# ₹8,199
# -----------------------
# realme Narzo 30A (Laser Black, 64 GB)
#
# Searching in amazon:
# Amazon:
# REALME NARZO 20 VICTORY BLUE, 4GB RAM, 128GB STORAGE
# ₹10,799
# -----------------------
# realme 7 (Mist Blue, 128 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# realme 7 (Mist Blue, 64 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# POCO M3 (Power Black, 64 GB)
#
# Searching in amazon:
# Amazon:
# POCO M3 (COOL BLUE, 6GB RAM, 64GB STORAGE)
# ₹10,499
# -----------------------
# Infinix Smart HD 2021 (Topaz Blue, 32 GB)
#
# Searching in amazon:
# Amazon:
# INFINIX SMART HD 2021 (OBSIDIAN BLACK,32 GB) (2 GB RAM) (OBSIDIAN BLACK)
# ₹8,499
# -----------------------
# Infinix Smart HD 2021 (Obsidian Black, 32 GB)
#
# Searching in amazon:
# Amazon:
# INFINIX SMART HD 2021 (OBSIDIAN BLACK,32 GB) (2 GB RAM) (OBSIDIAN BLACK)
# ₹8,499
# -----------------------
# REDMI 9i (Nature Green, 64 GB)
#
# Searching in amazon:
# Amazon:
# REDMI 9I (MIDNIGHT BLACK, 4GB RAM, 64GB STORAGE)
# ₹8,199
# -----------------------
# POCO M3 (Yellow, 64 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# realme 7i (Fusion Green, 128 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# realme 7i (Fusion Blue, 64 GB)
#
# Searching in amazon:
# amazon: No product found!
# -----------------------
# realme 7i (Fusion Blue, 128 GB)
#
# Searching in amazon:
# Amazon:
# REALME 7I, 4GB RAM, 64GB STORAGE
# ₹13,889
# -----------------------
# Empty DataFrame
# Columns: [Product_name_Flipkart, Flipkart_price, Product_name_Amazon, Amazon_price]
# Index: []
